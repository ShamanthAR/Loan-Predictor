# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'C:\Users\shamanth a r\Desktop\ML_PYTHON_INTERNSHIP\Loan Predictor.ui'
#
# Created by: PyQt5 UI code generator 5.15.2
#
# WARNING: Any manual changes made to this file will be lost when pyuic5 is
# run again.  Do not edit this file unless you know what you are doing.


from PyQt5 import QtCore, QtGui, QtWidgets


class Ui_LoanPredictor(object):
    def setupUi(self, LoanPredictor):
        LoanPredictor.setObjectName("LoanPredictor")
        LoanPredictor.resize(1236, 907)
        LoanPredictor.setStyleSheet("color:rgb(255, 255, 255);\n"
"background:rgb(0, 170, 127);\n"
"")
        self.Title = QtWidgets.QLabel(LoanPredictor)
        self.Title.setGeometry(QtCore.QRect(14, 10, 1211, 121))
        self.Title.setStyleSheet("font: 24pt \"Architects Daughter\";\n"
"text-decoration: underline;\n"
"font-weight:Bold;")
        self.Title.setAlignment(QtCore.Qt.AlignCenter)
        self.Title.setObjectName("Title")
        self.LblGender = QtWidgets.QLabel(LoanPredictor)
        self.LblGender.setGeometry(QtCore.QRect(80, 170, 261, 41))
        self.LblGender.setStyleSheet("font: 12pt \"Architects Daughter\";")
        self.LblGender.setObjectName("LblGender")
        self.LblMarried = QtWidgets.QLabel(LoanPredictor)
        self.LblMarried.setGeometry(QtCore.QRect(150, 250, 181, 51))
        self.LblMarried.setStyleSheet("font: 10pt \"Architects Daughter\";")
        self.LblMarried.setObjectName("LblMarried")
        self.LblDependents = QtWidgets.QLabel(LoanPredictor)
        self.LblDependents.setGeometry(QtCore.QRect(150, 320, 181, 51))
        self.LblDependents.setStyleSheet("font: 10pt \"Architects Daughter\";")
        self.LblDependents.setObjectName("LblDependents")
        self.LblEducation = QtWidgets.QLabel(LoanPredictor)
        self.LblEducation.setGeometry(QtCore.QRect(20, 410, 321, 51))
        self.LblEducation.setStyleSheet("font: 10pt \"Architects Daughter\";")
        self.LblEducation.setObjectName("LblEducation")
        self.LblSelfEmployed = QtWidgets.QLabel(LoanPredictor)
        self.LblSelfEmployed.setGeometry(QtCore.QRect(100, 480, 231, 51))
        self.LblSelfEmployed.setStyleSheet("font: 10pt \"Architects Daughter\";")
        self.LblSelfEmployed.setObjectName("LblSelfEmployed")
        self.LblCoAppIncome = QtWidgets.QLabel(LoanPredictor)
        self.LblCoAppIncome.setGeometry(QtCore.QRect(10, 570, 321, 51))
        self.LblCoAppIncome.setStyleSheet("font: 10pt \"Architects Daughter\";")
        self.LblCoAppIncome.setObjectName("LblCoAppIncome")
        self.InptGender = QtWidgets.QLineEdit(LoanPredictor)
        self.InptGender.setGeometry(QtCore.QRect(340, 170, 251, 41))
        self.InptGender.setStyleSheet("background:rgb(255, 255, 255);\n"
"font: 10pt \"Architects Daughter\";\n"
"color:black;")
        self.InptGender.setPlaceholderText("")
        self.InptGender.setObjectName("InptGender")
        self.InptMarried = QtWidgets.QLineEdit(LoanPredictor)
        self.InptMarried.setGeometry(QtCore.QRect(340, 250, 251, 41))
        self.InptMarried.setStyleSheet("background:rgb(255, 255, 255);\n"
"font: 10pt \"Architects Daughter\";\n"
"color:black;\n"
"\n"
"")
        self.InptMarried.setObjectName("InptMarried")
        self.InptDependents = QtWidgets.QLineEdit(LoanPredictor)
        self.InptDependents.setGeometry(QtCore.QRect(340, 330, 251, 41))
        self.InptDependents.setStyleSheet("background:rgb(255, 255, 255);\n"
"font: 10pt \"Architects Daughter\";\n"
"color:black;")
        self.InptDependents.setObjectName("InptDependents")
        self.InptEducation = QtWidgets.QLineEdit(LoanPredictor)
        self.InptEducation.setGeometry(QtCore.QRect(340, 410, 251, 41))
        self.InptEducation.setStyleSheet("background:rgb(255, 255, 255);\n"
"font: 10pt \"Architects Daughter\";\n"
"color:black;")
        self.InptEducation.setObjectName("InptEducation")
        self.InptSelfEmployed = QtWidgets.QLineEdit(LoanPredictor)
        self.InptSelfEmployed.setGeometry(QtCore.QRect(340, 490, 251, 41))
        self.InptSelfEmployed.setStyleSheet("background:rgb(255, 255, 255);\n"
"font: 10pt \"Architects Daughter\";\n"
"color:black;")
        self.InptSelfEmployed.setObjectName("InptSelfEmployed")
        self.InptCoAppIncome = QtWidgets.QLineEdit(LoanPredictor)
        self.InptCoAppIncome.setGeometry(QtCore.QRect(340, 570, 251, 41))
        self.InptCoAppIncome.setStyleSheet("background:rgb(255, 255, 255);\n"
"font: 10pt \"Architects Daughter\";\n"
"color:black;")
        self.InptCoAppIncome.setObjectName("InptCoAppIncome")
        self.LblCreditHistory = QtWidgets.QLabel(LoanPredictor)
        self.LblCreditHistory.setGeometry(QtCore.QRect(710, 160, 211, 51))
        self.LblCreditHistory.setStyleSheet("font: 10pt \"Architects Daughter\";")
        self.LblCreditHistory.setObjectName("LblCreditHistory")
        self.LblPropertyArea = QtWidgets.QLabel(LoanPredictor)
        self.LblPropertyArea.setGeometry(QtCore.QRect(690, 240, 241, 51))
        self.LblPropertyArea.setStyleSheet("font: 10pt \"Architects Daughter\";")
        self.LblPropertyArea.setObjectName("LblPropertyArea")
        self.LblApplicantIncomeLog = QtWidgets.QLabel(LoanPredictor)
        self.LblApplicantIncomeLog.setGeometry(QtCore.QRect(670, 320, 261, 51))
        self.LblApplicantIncomeLog.setStyleSheet("font: 10pt \"Architects Daughter\";")
        self.LblApplicantIncomeLog.setObjectName("LblApplicantIncomeLog")
        self.lblLoanAmount = QtWidgets.QLabel(LoanPredictor)
        self.lblLoanAmount.setGeometry(QtCore.QRect(700, 390, 221, 51))
        self.lblLoanAmount.setStyleSheet("font: 10pt \"Architects Daughter\";")
        self.lblLoanAmount.setObjectName("lblLoanAmount")
        self.LblLoanAmountTerm = QtWidgets.QLabel(LoanPredictor)
        self.LblLoanAmountTerm.setGeometry(QtCore.QRect(660, 480, 271, 51))
        self.LblLoanAmountTerm.setStyleSheet("font: 10pt \"Architects Daughter\";")
        self.LblLoanAmountTerm.setObjectName("LblLoanAmountTerm")
        self.LblToalIncome = QtWidgets.QLabel(LoanPredictor)
        self.LblToalIncome.setGeometry(QtCore.QRect(720, 560, 201, 51))
        self.LblToalIncome.setStyleSheet("font: 10pt \"Architects Daughter\";")
        self.LblToalIncome.setObjectName("LblToalIncome")
        self.InptCreditHistory = QtWidgets.QLineEdit(LoanPredictor)
        self.InptCreditHistory.setGeometry(QtCore.QRect(930, 170, 251, 41))
        self.InptCreditHistory.setStyleSheet("background:rgb(255, 255, 255);\n"
"font: 10pt \"Architects Daughter\";\n"
"color:black;")
        self.InptCreditHistory.setObjectName("InptCreditHistory")
        self.InptPropertyArea = QtWidgets.QLineEdit(LoanPredictor)
        self.InptPropertyArea.setGeometry(QtCore.QRect(930, 250, 251, 41))
        self.InptPropertyArea.setStyleSheet("background:rgb(255, 255, 255);\n"
"font: 10pt \"Architects Daughter\";\n"
"color:black;")
        self.InptPropertyArea.setObjectName("InptPropertyArea")
        self.InptAppIncome = QtWidgets.QLineEdit(LoanPredictor)
        self.InptAppIncome.setGeometry(QtCore.QRect(930, 320, 251, 41))
        self.InptAppIncome.setStyleSheet("background:rgb(255, 255, 255);\n"
"font: 10pt \"Architects Daughter\";\n"
"color:black;")
        self.InptAppIncome.setObjectName("InptAppIncome")
        self.InptLoanAmount = QtWidgets.QLineEdit(LoanPredictor)
        self.InptLoanAmount.setGeometry(QtCore.QRect(930, 400, 251, 41))
        self.InptLoanAmount.setStyleSheet("background:rgb(255, 255, 255);\n"
"font: 10pt \"Architects Daughter\";\n"
"color:black;")
        self.InptLoanAmount.setObjectName("InptLoanAmount")
        self.InptLoanAmountTerm = QtWidgets.QLineEdit(LoanPredictor)
        self.InptLoanAmountTerm.setGeometry(QtCore.QRect(930, 480, 251, 41))
        self.InptLoanAmountTerm.setStyleSheet("background:rgb(255, 255, 255);\n"
"font: 10pt \"Architects Daughter\";\n"
"color:black;")
        self.InptLoanAmountTerm.setObjectName("InptLoanAmountTerm")
        self.InptTotalIncome = QtWidgets.QLineEdit(LoanPredictor)
        self.InptTotalIncome.setGeometry(QtCore.QRect(930, 560, 251, 41))
        self.InptTotalIncome.setStyleSheet("background:rgb(255, 255, 255);\n"
"font: 10pt \"Architects Daughter\";\n"
"color:black;")
        self.InptTotalIncome.setObjectName("InptTotalIncome")
        self.BtnPredict = QtWidgets.QPushButton(LoanPredictor)
        self.BtnPredict.setGeometry(QtCore.QRect(610, 670, 201, 51))
        self.BtnPredict.clicked.connect(self.Predict)
        self.BtnPredict.setStyleSheet("Background:rgb(255, 255, 255);\n"
"font: 18pt \"Architects Daughter\";\n"
"color:rgb(0, 170, 127)")
        self.BtnPredict.setObjectName("BtnPredict")
        self.LblResult = QtWidgets.QLabel(LoanPredictor)
        self.LblResult.setGeometry(QtCore.QRect(320, 750, 731, 131))
        self.LblResult.setStyleSheet("font: 18pt \"Architects Daughter\";")
        self.LblResult.setText("")
        self.LblResult.setObjectName("LblResult")

        self.retranslateUi(LoanPredictor)
        QtCore.QMetaObject.connectSlotsByName(LoanPredictor)

    def retranslateUi(self, LoanPredictor):
        _translate = QtCore.QCoreApplication.translate
        LoanPredictor.setWindowTitle(_translate("LoanPredictor", "Form"))
        self.Title.setText(_translate("LoanPredictor", "Loan Predictor"))
        self.LblGender.setText(_translate("LoanPredictor", "Gender : Male(1)  Female(0)"))
        self.LblMarried.setText(_translate("LoanPredictor", "Married : Yes(0)  No(1)"))
        self.LblDependents.setText(_translate("LoanPredictor", "Dependents : ( 1 or 0 )"))
        self.LblEducation.setText(_translate("LoanPredictor", "Education : Graduate(1) No Graduate(0)"))
        self.LblSelfEmployed.setText(_translate("LoanPredictor", "Self Employed : Yes(1) No(0)"))
        self.LblCoAppIncome.setText(_translate("LoanPredictor", "CoApplicant Income : (0.0 to 25,000.00)"))
        self.LblCreditHistory.setText(_translate("LoanPredictor", "Credit History: (1.0 to 0.0)"))
        self.LblPropertyArea.setText(_translate("LoanPredictor", "Property area : ( 0 or 1 ) "))
        self.LblApplicantIncomeLog.setText(_translate("LoanPredictor", "Aplplicant Income : (0.0 to 10.00)"))
        self.lblLoanAmount.setText(_translate("LoanPredictor", "Loan Amount :( 3.0 to 6.5 )"))
        self.LblLoanAmountTerm.setText(_translate("LoanPredictor", "Loan Amount Term : ( 1.0 to 6.5 )"))
        self.LblToalIncome.setText(_translate("LoanPredictor", "Total Income : ( 7 to 14 )"))
        self.BtnPredict.setText(_translate("LoanPredictor", "Predict"))

    def Predict(self):
        import pandas as pd
        import numpy as np
        import matplotlib.pyplot as plt
        # %matplotlib inline
        import seaborn as sns

        path="C:/Users/shamanth a r/Desktop/ML_PYTHON_INTERNSHIP/projects/SVM/loanpredictiondataset/train.csv"
        df = pd.read_csv(path)
        #handle Numerical missing data
        df['LoanAmount'] = df['LoanAmount'].fillna(df['LoanAmount'].mean())
        df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
        df['Credit_History'] = df['Credit_History'].fillna(df['Credit_History'].mean())

        #Handle the Categorical missing data
        df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])
        df['Married'] = df['Married'].fillna(df['Married'].mode()[0])
        df['Dependents'] = df['Dependents'].fillna(df['Dependents'].mode()[0])
        df['Self_Employed'] = df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])


        #Data Analysis(Exploratory)
        # Since the ApplicantIncome And CoapplicantIncome were both some sort of incomes. So added and stored in a new column
        df['Total_Income'] = df['ApplicantIncome'] + df['CoapplicantIncome']

        #Data Transformation
        #Those data which were not normally distributed are normally distributed by using the log method
        df['ApplicantIncomeLog'] = np.log(df['ApplicantIncome'])
        df['CoapplicantIncome_Log'] = np.log(df['CoapplicantIncome'])
        df['LoanAmount_Log'] = np.log(df['LoanAmount'])
        df['Loan_Amount_Term_Log'] = np.log(df['Loan_Amount_Term'])
        df['Total_Income_Log'] = np.log(df['Total_Income'])


        #Dropping the unWanted columns which are not of use for the model
        cols= ['ApplicantIncome','ApplicantIncome','LoanAmount','Loan_Amount_Term','Total_Income','Loan_ID','CoapplicantIncome_Log']
        df = df.drop(columns=cols,axis=1)

        #Handling the Categorical values using the OneHot Encoding
        cols = ['Gender','Married','Dependents','Education','Self_Employed','Property_Area','Loan_Status']
        #Running a for loop And encoding the columns one by one.
        #get_dummies() is used for data manipulation. It converts categorical data into dummy or indicator variables
        for col in cols:
            df[col] = pd.get_dummies(df[col], drop_first = True)

        #Getting things ready for the test dataset
        path="C:/Users/shamanth a r/Desktop/ML_PYTHON_INTERNSHIP/projects/SVM/loanpredictiondataset/test.csv"
        test = pd.read_csv(path)

        
        #handle Numerical missing data
        test['LoanAmount'] = test['LoanAmount'].fillna(test['LoanAmount'].mean())
        test['Loan_Amount_Term'] = test['Loan_Amount_Term'].fillna(test['Loan_Amount_Term'].mean())
        test['Credit_History'] = test['Credit_History'].fillna(test['Credit_History'].mean())

        #Handle the Categorical missing data
        test['Gender'] = test['Gender'].fillna(test['Gender'].mode()[0])
        test['Married'] = test['Married'].fillna(test['Married'].mode()[0])
        test['Dependents'] = test['Dependents'].fillna(test['Dependents'].mode()[0])
        test['Self_Employed'] = test['Self_Employed'].fillna(test['Self_Employed'].mode()[0])

        #Data Analysis(Exploratory)
        # Since the ApplicantIncome And CoapplicantIncome were both some sort of incomes. So added and stored in a new column
        test['Total_Income'] = test['ApplicantIncome'] + test['CoapplicantIncome']

        #Data Transformation
        #Those data which were not normally distributed are normally distributed by using the log method
        test['ApplicantIncomeLog'] = np.log(test['ApplicantIncome'])
        test['CoapplicantIncome_Log'] = np.log(test['CoapplicantIncome'])
        test['LoanAmount_Log'] = np.log(test['LoanAmount'])
        test['Loan_Amount_Term_Log'] = np.log(test['Loan_Amount_Term'])
        test['Total_Income_Log'] = np.log(test['Total_Income'])


        #Dropping the unWanted columns which are not of use for the model
        cols= ['ApplicantIncome','ApplicantIncome','LoanAmount','Loan_Amount_Term','Total_Income','Loan_ID','CoapplicantIncome_Log']
        test = test.drop(columns=cols,axis=1)

        #Handling the Categorical values using the OneHot Encoding
        cols = ['Gender','Married','Dependents','Education','Self_Employed','Property_Area']
        #Running a for loop And encoding the columns one by one.
        #get_dummies() is used for data manipulation. It converts categorical data into dummy or indicator variables
        for col in cols:
            test[col] = pd.get_dummies(test[col], drop_first = True)
        # Train Test splitting
        # Specifying dependent and independent variables
        x = df.drop(columns=['Loan_Status'],axis=1)
        y = df['Loan_Status']

        from sklearn.model_selection import train_test_split
        x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

        from sklearn.linear_model import LogisticRegression
        model = LogisticRegression()
        model.fit(x_train,y_train)

        #Taking the inputs from the Users
        Gender = int(self.InptGender.text())
        Married = int(self.InptMarried.text())
        Dependents = int(self.InptDependents.text()) 
        Education = int(self.InptEducation.text())
        Self_Employed = int(self.InptSelfEmployed.text())
        CoapplicantIncome = float(self.InptCoAppIncome.text())
        Credit_History = float(self.InptCreditHistory.text())
        Property_Area = int(self.InptPropertyArea.text())
        ApplicantIncomeLog = float(self.InptAppIncome.text())
        LoanAmount_Log = float(self.InptLoanAmount.text())
        Loan_Amount_Term_Log = float(self.InptLoanAmountTerm.text())
        Total_Income_Log = float(self.InptTotalIncome.text())
        y_pred = model.predict([[Gender,Married,Dependents,Education,Self_Employed,CoapplicantIncome,Credit_History,Property_Area,ApplicantIncomeLog,LoanAmount_Log,Loan_Amount_Term_Log,Total_Income_Log]])
        if (y_pred[0] == 1):
            Output = 'Loan will be approved!!!'
            self.LblResult.setText(Output)
            print(y_pred[0])
        else:
            Output = 'Loan will not be approved!!'
            self.LblResult.setText(Output)
            print(y_pred[0])
  
if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    LoanPredictor = QtWidgets.QWidget()
    ui = Ui_LoanPredictor()
    ui.setupUi(LoanPredictor)
    LoanPredictor.show()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\shamanth a r\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
